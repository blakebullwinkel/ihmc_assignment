# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pilot1_blue = pd.read_csv(r'C:\Users\Blake Bullwinkel\Downloads\WSSCGQWVS Corrected Sim Segments\Blue\Group_1_6454302531282_P8543_Blue_9_J.txt',sep='	')
pilot2_blue = pd.read_csv(r'C:\Users\Blake Bullwinkel\Downloads\WSSCGQWVS Corrected Sim Segments\Blue\Group_1_7167357727955_P5427_Blue_9_J.txt',sep='	')
pilot3_blue = pd.read_csv(r'C:\Users\Blake Bullwinkel\Downloads\WSSCGQWVS Corrected Sim Segments\Blue\Group_2_6306616351170_P7442_Blue_9_J.txt',sep='	')

pilot1_gold = pd.read_csv(r'C:\Users\Blake Bullwinkel\Downloads\WSSCGQWVS Corrected Sim Segments\Gold\Group_1_6152807954238_P3061_Gold_9_J.txt',sep='	')
pilot2_gold = pd.read_csv(r'C:\Users\Blake Bullwinkel\Downloads\WSSCGQWVS Corrected Sim Segments\Gold\Group_1_6206460016536_P7234_Gold_9_J.txt',sep='	')
pilot3_gold = pd.read_csv(r'C:\Users\Blake Bullwinkel\Downloads\WSSCGQWVS Corrected Sim Segments\Gold\Group_2_6168263773276_P5454_Gold_9_J.txt',sep='	')

# %%
pilot1.head()
# Out:
#    start_timestamp  Aircraft_Quality  Timestamp_nano  EntityID_code  \
# 0    6830581016869               NaN             NaN            NaN
# 1    6830599925072               NaN             NaN            NaN
# 2    6830616593997               1.0    9.504500e+13            0.0
# 3    6830616594147               1.0    9.504500e+13            0.0
# 4    6830616594147               1.0    9.504500e+13            0.0
#
#    Latitude_deg  Longitude_deg   Altitude_ft  Heading_deg  Pitch_deg  \
# 0           NaN            NaN           NaN          NaN        NaN
# 1           NaN            NaN           NaN          NaN        NaN
# 2     33.628700     -87.307526  15841.592773   324.090424  -3.219537
# 3     33.628700     -87.307526  15841.592773   324.052704  -3.399167
# 4     33.629116     -87.307892  15829.331055   324.052704  -3.399167
#
#     Roll_deg  ...  TaskUniqueID_code.1  TestCategory_code  \
# 0        NaN  ...                  NaN                NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(pilot1.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
pilot1_blue_location = pilot1_blue[['start_timestamp','Altitude_ft','Latitude_deg','Longitude_deg']].dropna()
pilot1_blue_waypoints = pilot1_blue[['PreviousWayPoint_code','NextWayPoint_code','TargetWayPoint_code']].dropna()

pilot1_gold_location = pilot1_gold[['start_timestamp','Altitude_ft','Latitude_deg','Longitude_deg']].dropna()
pilot1_gold_waypoints = pilot1_gold[['PreviousWayPoint_code','NextWayPoint_code','TargetWayPoint_code']].dropna()

# %%
sns.lineplot(x='start_timestamp',y='Altitude_ft',data=pilot1_blue_location)

# %%
sns.lineplot(x='Longitude_deg',y='Latitude_deg',data=pilot1_blue_location)
# plt.xlim(reversed(plt.xlim()))

# %%
pilot1_blue_waypoints.tail()
# Out:
#       PreviousWayPoint_code  NextWayPoint_code  TargetWayPoint_code
# 8485                   32.0               33.0                 34.0
# 8491                   32.0               33.0                 34.0
# 8498                   32.0               33.0                 34.0
# 8505                   32.0               33.0                 34.0
# 8512                   32.0               33.0                 34.0
